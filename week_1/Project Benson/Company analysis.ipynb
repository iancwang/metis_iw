# %% [markdown]
# # Project Benson
# ## Company Analysis
#
#
#
# Amy, Ian and Devon for Metis

# %% [markdown]
# _____

# %%
import sys

# %%
# imports a library 'pandas', names it as 'pd'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

import pprint

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

import dateutil.parser
from datetime import *

# %% [markdown]
# _____

# %% [markdown]
# # DATA SETS

# %% [markdown]
# ### New York zip codes sorted by borough
#
# https://www.health.ny.gov/statistics/cancer/registry/appendix/neighborhoods.htm
#
# Copy data from website above
#
# Some were missing so a few were manually added to this data frame

# %%
# Map for the zip code areas

zip_code_dict = {'Bronx':[10453, 10457, 10460,10458, 10467, 10468,10451, 10452, 10456,10454, 10455, 
                          10459, 10474,10463, 10471,10466, 10469, 10470, 10475,10461, 10462,10464, 
                          10465, 10472, 10473],
'Brooklyn':[11212, 11213, 11216, 11233, 11238,11209, 11214, 11228,11204, 11218, 11219, 11230,11234, 
            11236, 11239,11223, 11224, 11229, 11235,11201, 11205, 11215, 11217, 11231,11203, 11210, 11225,
            11226,11207, 11208,11211, 11222,11220, 11232,11206, 11221, 11237,11249],
'Manhattan':[10169,10281,10026, 10027, 10030, 10037, 10039,10001, 10011, 10018, 10019, 10020, 10036,10029, 10035,
             10121,10010, 10016, 10017, 10022,10012, 10013, 10014,10004, 10005, 10006, 10007, 10038, 10280,
             10118,10002, 10003, 10009,10021, 10028, 10044, 10065, 10075, 10128,10023, 10024, 10025,10031, 
             10023,10123,10119,10032, 10033, 10034, 10040],
'Queens':[11354, 11361, 11362, 11363, 11364,1354, 11355, 11356, 11357, 11358, 11359, 11360,11365, 11366, 
          11367,11412, 11423, 11432, 11433, 11434, 11435, 11436,11101, 11102, 11103, 11104, 11105, 
          11106,11374, 11375, 11379, 11385,1691, 11692, 11693, 11694, 11695, 11697,1004, 11005, 
          11411, 11413, 11422, 11426, 11427, 11428, 11429,11414, 11415, 11416, 11417, 11418, 11419, 
          11420, 11421,11368, 11369, 11370, 11372, 11373, 11377, 11378],
'Staten Island':[10302, 10303, 10310,10306, 10307, 10308, 10309, 10312,10301, 10304, 10305,10314]}

# %% [markdown]
# ### New York's top 20 stations by traffic data
#
# Added zip code of each station for future sorting

# %%
top_stations = {1:['34 ST-HERALD SQ',10001],
                2:['TIMES SQ-42 ST',10018],
                3:['GRD CNTRL-42 ST',10017],
                4:['47-50 STS ROCK',10020],
                5:['14 ST-UNION SQ',10003],
                6:['23 ST',10010],
                7:['34 ST-PENN STA',10001],
                8:['CHAMBERS ST',10007],
                9:['59 ST COLUMBUS',10023],
                10:['59 ST',11220],
                11:['FULTON ST',10007],
                12:['42 ST-BRYANT PK',10021],
                13:['LEXINGTON AV/53',10022],
                14:['50 ST',10019],
                15:['CANAL ST',10013],
                16:['42 ST-PORT AUTH',10036],
                17:['86 ST',10028],
                18:['FLUSHING-MAIN',11354],
                19:['14 ST',10011],
                20:['125 ST',10027]}

# %% [markdown]
# ### Tech companies in New York - 50 largest
#
# https://www.builtinnyc.com/2017/11/07/nyc-top-100-tech-companies-2017
#
# Copy data from website above

# %%
tech_data = '''bloomberg NYC tech company

Bloomberg 10022
View Profile
We are hiring
Rank: 1 | Employees: 9,000 | Founded: 1981 | Software

Bloomberg is Hiring | View 57 Jobs
 

Oath NYC tech company

Oath 10003
View Profile
FOLLOW
Rank: 2 | Employees: 1,400 | Founded: 2017 | Media

 

CA Technologies NYC tech company

CA Technologies10022
View Profile
FOLLOW
Rank: 3 | Employees: 1,230 | Founded: 1976 | Software

 

vice nyc tech company

Vice Media11249
View Profile
We are hiring
Rank: 4 | Employees: 1,217 | Founded: 1994 | Media

Vice Media is Hiring | View 103 Jobs
 

blue apron nyc tech company

Blue Apron10013
View Profile
FOLLOW
Rank: 5 | Employees: 890 | Founded: 2012 | Food

 

etrade nyc tech company

E*Trade10036
View Profile
FOLLOW
Rank: 6 | Employees: 827 | Founded: 1982 | Fintech

 

buzzfeed nyc tech company

BuzzFeed10003
View Profile
FOLLOW
Rank: 7 | Employees: 730 | Founded: 2006 | Media

 

yext nyc tech company

Yext10010
View Profile
We are hiring
Rank: 8 | Employees: 675 | Founded: 2006 | Web

Yext is Hiring | View 39 Jobs
 

freshdirect nyc tech company

FreshDirect11101
View Profile
FOLLOW
Rank: 9 | Employees: 657 | Founded: 2002 | Food

 

etsy nyc tech company

Etsy11201
View Profile
FOLLOW
Rank: 10 | Employees: 622 | Founded:2005 | E-commerce

 

appnexus nyc tech company

AppNexus10010
View Profile
FOLLOW
Rank: 11 | Employees: 583 | Founded: 2007 | Web

 

refinery29 nyc tech company

Refinery2910007
View Profile
FOLLOW
Rank: 12 | Employees: 558 | Founded: 2005 | Media

 

peloton nyc tech company

Peloton10022
View Profile
FOLLOW
Rank: 13 | Employees: 515 | Founded: 2012 | Fitness

 

informationbuilders nyc tech company

Information Builders10121
View Profile
FOLLOW
Rank: 14 | Employees: 485 | Founded: 1975 | Software

 

flatiron health nyc tech company

Flatiron Health10010
View Profile
We are hiring
Rank: 15 | Employees: 460 | Founded: 2012 | Healthtech

Flatiron Health is Hiring | View 54 Jobs
 

shutterstock nyc tech company

Shutterstock10118
View Profile
We are hiring
Rank: 16 | Employees: 450 | Founded: 2003 | Web

Shutterstock is Hiring | View 33 Jobs
 

squarespace nyc tech company

Squarespace10281
View Profile
We are hiring
Rank: 17 | Employees: 426 | Founded: 2004 | Web

Squarespace is Hiring | View 42 Jobs
 

infor nyc tech company

Infor10011
View Profile
FOLLOW
Rank: 18 | Employees: 420 | Founded: 2002 | Software

 

group nine media nyc tech

Group Nine Media10012
View Profile
We are hiring
Rank: 18* | Employees: 420 | Founded: 2016 | Media

Group Nine Media is Hiring | View 23 Jobs
 

oscar nyc tech company

Oscar10012
View Profile
FOLLOW
Rank: 19 | Employees: 400 | Founded: 2013 | Healthtech

 

gilt groupe nyc tech

Gilt Groupe10281
View Profile
FOLLOW
Rank: 19 | Employees: 400 | Founded: 2007 | E-commerce

 

intersection nyc tech company

Intersection10001
View Profile
FOLLOW
Rank: 21 | Employees: 380 | Founded: 2015 | Marketing

 

namely nyc tech company

Namely10007
View Profile
We are hiring
Rank: 21 | Employees: 380 | Founded: 2012 | Software

Namely is Hiring | View 25 Jobs
 

business insider nyc tech company

The Business Insider10011
View Profile
FOLLOW
Rank: 23 | Employees: 350 | Founded: 2007 | Media

 

xo group nyc tech company

XO Group Inc10007
View Profile
FOLLOW
Rank: 23 | Employees: 350 | Founded: 1996 | Media

 

mediamath nyc tech company

MediaMath10007
View Profile
sailthru nyc tech company

Sailthru
View Profile
FOLLOW
Rank: 96 | Employees: 130 | Founded: 2008 | Marketing

 

tapad nyc tech company

Tapad
View Profile
FOLLOW
Rank: 98 | Employees: 125 | Founded: 2010 | Marketing

 

yodle nyc tech company

Yodle
View Profile
FOLLOW
Rank: 99 | Employees: 124 | Founded: 2005 | Web

 

sisense nyc tech company

Sisense
View Profile
We are hiring
Rank: 100 | Employees: 122 | Founded: 2004 | Software'''

# %% [markdown]
# ### New York most pilanthropic companies - top 6
#
# Company - Zip Code - Millions of cash donated

# %%
philanthropic_companies = {'Verizon':[10013, 56.4], 
                           'CitiGroup':[10013, 142.8],  
                           'JPMorgan Chase':[10017, 236.2], 
                           'Goldman Sachs':[10013, 276.41],
                           'Bristol Myers Squid':[10022,27], 
                           'Phizer':[10017, 93.33]}

# %% [markdown]
# ### New York largest employers
#
# Haven't used this data yet but would be a next step to analyze

# %%
highest_employer = {'JPMorgan Chase & Co.':10017,
'Citigroup Inc.':10013,
'Verizon Communications Inc.':10013,
'Cerberus Capital Management, L.P.':10022,
'Citibank, N.A.':10013,
'ABM Industries':10006,
'GTE':0,
'Philip Morris International Inc':10017,
'Pfizer Inc.':10017,
'Omnicom Group Inc.':10022,
'Metropolitan Transportation Authority Disaster Relief Fund':10004,
'MetLife Insurance and Financial Service Provider':0,
'Deloitte LLP':0,
'American International Group, Inc.':0,
'American Express Company   Global payments company':0,
'MacAndrews & Forbes Incorporated':0,
'Alcoa Inc. Aluminum producer':0,
'LEH FM Holdings Llc':0,
'Icahn Enterprises Holdings L.P.':0,
'Icahn Enterprises L.P.':0,
'American Express Travel Related Services Company, Inc.':0,
'Thomson Reuters Corporation':0,
'Morgan Stanley   investment bank':0,
'Marsh & McLennan Companies, Inc.':0,
'Time Warner Cable Inc.':0,
'The Bank of New York Mellon Corporation':0,
'L-3 Communications Corporation':0,
'L-3 Communications Holdings, Inc.':0,
'Merrill Lynch':0,
'The Interpublic Group of Companies, Inc.':0,
'Foot Locker, Inc.':0,
'The Estée Lauder Companies Inc':0,
'Deloitte & Touche LLP':0}

# %% [markdown]
# ____

# %% [markdown]
# ## Transform data list and dictionaries to DATA FRAMES

# %% [markdown]
# ### Data Cleaning on Tech Companies

# %%
# various options in pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

# %%
# Start cleaning the data

tech_data = tech_data.replace(' ','')
tech_data = tech_data.replace('\n\n','\n')

# %%
# Withdraw useful info - name, number of employees, and zip code and make a dictionary

company_dict = {}

end = 0
    
for i in range(50):  
    # Find the names
    start_name = tech_data.find('\n', end)
    end_name = tech_data.find('\n',start_name+1)
    name = tech_data[start_name+1:end_name]
    
    company = name[0:len(name)-5]
    zip_code = int(name[-5:])

    #Find the number of employees
    start_emp = tech_data.find('|',end_name)
    end_emp = tech_data.find('|',start_emp+1)
    emp = int((tech_data[start_emp+11:end_emp]).replace(',',''))

    company_dict[company] = [emp, zip_code]
    
    end = tech_data.find('\n\n', end_emp)
    end = tech_data.find('\n', end+3)

# %%
# Turn companies into data frame
df = pd.DataFrame.from_dict(company_dict, 'index')
df.rename(columns = {0 : 'Num_of_employees'}, inplace = True)
df.rename(columns = {1 : 'Zip_code'}, inplace = True)

# %%
# Turning a zip code into a borough. This could be done much cleaner but this is the quick and dirty

leng = len(df.index)

df['boroughs'] = ['a'] * leng

ind = list(zip_code_dict.keys())
for i in range(len(df.index)):
    find = df['Zip_code'][i]
    if find in zip_code_dict[ind[0]]:
        value = ind[0]
        df['boroughs'][i] = value
    if find in zip_code_dict[ind[1]]:
        value = ind[1]
        df['boroughs'][i] = value
    if find in zip_code_dict[ind[2]]:
        value = ind[2]
        df['boroughs'][i] = value
    if find in zip_code_dict[ind[3]]:
        value = ind[3]
        df['boroughs'][i] = value
    if find in zip_code_dict[ind[4]]:
        value = ind[4]
        df['boroughs'][i] = value
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Top tech companies data frame

# %%
df
# Out:
#                                Num_of_employees  Zip_code   boroughs
# Bloomberg                                  9000     10022  Manhattan
# Oath                                       1400     10003  Manhattan
# CATechnologies                             1230     10022  Manhattan
# ViceMedia                                  1217     11249   Brooklyn
# BlueApron                                   890     10013  Manhattan
# E*Trade                                     827     10036  Manhattan
# BuzzFeed                                    730     10003  Manhattan
# Yext                                        675     10010  Manhattan
# FreshDirect                                 657     11101     Queens
# Etsy                                        622     11201   Brooklyn
# AppNexus                                    583     10010  Manhattan
# Refinery29                                  558     10007  Manhattan
# ...                                         ...       ...        ...
# ...

# %% [markdown]
# ### Data Cleaning on Zip Code Dictionary

# %%
df_top = pd.DataFrame.from_dict(top_stations, 'index')
df_top.rename(columns = {0: 'Station'}, inplace = True)
df_top.rename(columns = {1 : 'Zip_code'}, inplace = True)

# %%
# Turning a zip code into a borough for top stations. This could be done much 
# cleaner but this is the quick and dirty 

leng = len(df_top.index)
df_top['boroughs'] = ['a'] * leng

ind = list(zip_code_dict.keys())
for i in range(1,len(df_top.index)+1):
    find = df_top['Zip_code'][i]
    if find in zip_code_dict[ind[0]]:
        value = ind[0]
        df_top['boroughs'][i] = value
    if find in zip_code_dict[ind[1]]:
        value = ind[1]
        df_top['boroughs'][i] = value
    if find in zip_code_dict[ind[2]]:
        value = ind[2]
        df_top['boroughs'][i] = value
    if find in zip_code_dict[ind[3]]:
        value = ind[3]
        df_top['boroughs'][i] = value
    if find in zip_code_dict[ind[4]]:
        value = ind[4]
        df_top['boroughs'][i] = value
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Highest Traffic Stations data frame

# %%
df_top
# Out:
#             Station  Zip_code   boroughs
# 1   34 ST-HERALD SQ     10001  Manhattan
# 2    TIMES SQ-42 ST     10018  Manhattan
# 3   GRD CNTRL-42 ST     10017  Manhattan
# 4    47-50 STS ROCK     10020  Manhattan
# 5    14 ST-UNION SQ     10003  Manhattan
# 6             23 ST     10010  Manhattan
# 7    34 ST-PENN STA     10001  Manhattan
# 8       CHAMBERS ST     10007  Manhattan
# 9    59 ST COLUMBUS     10023  Manhattan
# 10            59 ST     11220   Brooklyn
# 11        FULTON ST     10007  Manhattan
# 12  42 ST-BRYANT PK     10021  Manhattan
# 13  LEXINGTON AV/53     10022  Manhattan
# 14            50 ST     10019  Manhattan
# 15         CANAL ST     10013  Manhattan
# 16  42 ST-PORT AUTH     10036  Manhattan
# 17            86 ST     10028  Manhattan
# 18    FLUSHING-MAIN     11354     Queens
# 19            14 ST     10011  Manhattan
# 20           125 ST     10027  Manhattan

# %% [markdown]
# ### Data cleaning on most philanthropic companies dictionary

# %%
# Turn ph companies into data frame

df_ph = pd.DataFrame.from_dict(philanthropic_companies, 'index')
df_ph.rename(columns = {0: 'Zip_code'}, inplace = True)
df_ph.rename(columns = {1: 'Millions'}, inplace = True)
df_ph = df_ph.reset_index(level=0)
df_ph.rename(columns = {'index' : 'Philanthropic_Company'}, inplace = True)

# %%
# Turning a zip code into a borough. This could be done much cleaner but this is the quick and dirty 

leng = len(df_ph.index)
df_ph['boroughs'] = ['a'] * leng

ind = list(zip_code_dict.keys())
for i in range(0,len(df_ph.index)):
    find = df_ph['Zip_code'][i]
    if find in zip_code_dict[ind[0]]:
        value = ind[0]
        df_ph['boroughs'][i] = value
    if find in zip_code_dict[ind[1]]:
        value = ind[1]
        df_ph['boroughs'][i] = value
    if find in zip_code_dict[ind[2]]:
        value = ind[2]
        df_ph['boroughs'][i] = value
    if find in zip_code_dict[ind[3]]:
        value = ind[3]
        df_ph['boroughs'][i] = value
    if find in zip_code_dict[ind[4]]:
        value = ind[4]
        df_ph['boroughs'][i] = value
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Highest Philanthropic Companies data frame

# %%
df_ph
# Out:
#   Philanthropic_Company  Zip_code  Millions   boroughs
# 0               Verizon     10013     56.40  Manhattan
# 1             CitiGroup     10013    142.80  Manhattan
# 2        JPMorgan Chase     10017    236.20  Manhattan
# 3         Goldman Sachs     10013    276.41  Manhattan
# 4   Bristol Myers Squid     10022     27.00  Manhattan
# 5                Phizer     10017     93.33  Manhattan

# %% [markdown]
# ___

# %% [markdown]
# ## MERGING
#
# Take 3 data frames into one to sort out desiered stations to send staff

# %%
df = df.reset_index(level=0)
df.rename(columns = {'index' : 'Tech_Company'}, inplace = True)

# %%
df_top2 = (df_top
 .sort_values(by='Zip_code', ascending=True)
 .groupby(['Zip_code'])[['Station']].count())
df_top2
# Out:
#           Station
# Zip_code
# 10001           2
# 10003           1
# 10007           2
# 10010           1
# 10011           1
# 10013           1
# 10017           1
# 10018           1
# 10019           1
# 10020           1
# 10021           1
# 10022           1
# 10023           1
# 10027           1
# 10028           1
# 10036           1
# 11220           1
# 11354           1

# %%
df_ph2 = (df_ph
 .sort_values(by='Zip_code', ascending=True)
 .groupby(['Zip_code'])[['Millions']].count())
df_ph2
# Out:
#           Millions
# Zip_code
# 10013            3
# 10017            2
# 10022            1

# %%
df2 = (df
 .sort_values(by='Zip_code', ascending=True)
 .groupby(['Zip_code'])[['Tech_Company']].count())
df2
# Out:
#           Tech_Company
# Zip_code
# 10001                3
# 10003                4
# 10004                1
# 10007                4
# 10010                5
# 10011                6
# 10012                3
# 10013                2
# 10014                1
# 10017                1
# 10018                3
# 10020                1
# 10022                3
# 10036                3
# 10118                1
# 10119                1
# 10121                1
# 10169                1
# 10281                2
# 11101                1
# 11201                2
# 11249                1

# %%
df_top2 = df_top2.reset_index(level=0)
df2 = df2.reset_index(level=0)
df_ph2 = df_ph2.reset_index(level=0)

# %%
merged = (pd
          .merge(df2,df_top2,on='Zip_code',how='left')
          .sort_values(by='Tech_Company', ascending=False))[['Zip_code','Tech_Company','Station']]

# %%
merged = merged.reset_index(drop=True)

# %%
df_ph2.rename(columns = {'Millions' : 'Philanthropic_Company'}, inplace = True)

# %%
merged2 = (pd
          .merge(merged,df_ph2,on='Zip_code',how='left')
          .sort_values(by='Tech_Company', ascending=False))[['Zip_code','Tech_Company','Station','Philanthropic_Company']]

# %%
cols = merged2.columns.tolist()
cols2 = []
cols2 = [cols[0], cols[1], cols[3], cols[2]]
merged2 = merged2[cols2]

# 10011 and 10010 border each other
# 10012

# %%
merged2 = merged2.fillna(value=0)
merged2['Philanthropic_Company'] = merged2.Philanthropic_Company.astype(int)
merged2['Station'] = merged2.Station.astype(int)

# %%
merged2
# Out:
#     Zip_code  Tech_Company  Philanthropic_Company  Station
# 0      10011             6                      0        1
# 1      10010             5                      0        1
# 2      10007             4                      0        2
# 3      10003             4                      0        1
# 4      10001             3                      0        2
# 5      10012             3                      0        0
# 6      10018             3                      0        1
# 7      10022             3                      1        1
# 8      10036             3                      0        1
# 10     10013             2                      3        1
# 11     10281             2                      0        0
# 9      11201             2                      0        0
# 12     10121             1                      0        0
# 13     11101             1                      0        0
# 14     10169             1                      0        0
# ...

# %% [markdown]
# ____

# %% [markdown]
# ## FINAL STATIONS

# %% [markdown]
# We optimized the total number of tech and philanthropic companies near the train stations

# %%
keep_stations = {1:['34 ST-HERALD SQ',10001], # KEEP team 1, 2
                2:['TIMES SQ-42 ST',10018], # KEEP team 3
                3:['GRD CNTRL-42 ST',10017], # KEEP team 5
                5:['14 ST-UNION SQ',10003], # KEEP team 6
                6:['23 ST',10010], # KEEP team 7
                8:['CHAMBERS ST',10007], # KEEP team 9
                13:['LEXINGTON AV/53',10022], # KEEP team 10
                15:['CANAL ST',10013], # KEEP team 4
                19:['14 ST',10011]} # KEEP team 8

# %%
# Turn keep stations into data frame

df_ks = pd.DataFrame.from_dict(keep_stations, 'index')
df_ks.rename(columns = {0: 'Station'}, inplace = True)
df_ks.rename(columns = {1: 'Zip_code'}, inplace = True)
df_ks
# Out:
#             Station  Zip_code
# 1   34 ST-HERALD SQ     10001
# 2    TIMES SQ-42 ST     10018
# 3   GRD CNTRL-42 ST     10017
# 5    14 ST-UNION SQ     10003
# 6             23 ST     10010
# 8       CHAMBERS ST     10007
# 13  LEXINGTON AV/53     10022
# 15         CANAL ST     10013
# 19            14 ST     10011

# %%
df_ks2 = (df_ks
 .sort_values(by='Zip_code', ascending=True)
 .groupby(['Zip_code']).count())
df_ks3 = df_ks2.reset_index(level=0)
df_ks3.rename(columns = {'index' : 'Zip_code'}, inplace = True)

# %%
keep = merged2.drop(labels=['Station'],axis=1)
keep_merged = (pd
          .merge(keep,df_ks3,on='Zip_code',how='left')
          .sort_values(by='Tech_Company', ascending=False))

# %%
keep_merged = keep_merged.fillna(value=0)
keep_merged['Station'] = keep_merged.Station.astype(int)

# %%
df_final = keep_merged.sort_values(by=['Tech_Company','Philanthropic_Company','Station'], ascending=False)

# %%
recommend= df_final.loc[~(df_final['Station'] == 0)]

# %% [markdown]
# ### Recommendation Data Frame

# %%
recommend
# Out:
#     Zip_code  Tech_Company  Philanthropic_Company  Station
# 0      10011             6                      0        1
# 1      10010             5                      0        1
# 2      10007             4                      0        1
# 3      10003             4                      0        1
# 7      10022             3                      1        1
# 4      10001             3                      0        1
# 6      10018             3                      0        1
# 9      10013             2                      3        1
# 18     10017             1                      2        1
