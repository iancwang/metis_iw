# %%
from __future__ import print_function, division

# Necessary imports
# all of the imports
import pandas as pd
import numpy as np
import pickle 
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
% matplotlib inline
#figure % new figure window

import warnings
warnings.filterwarnings('ignore')
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Load Data
df = pd.read_csv('sea_listings.csv')

# %%
#df.columns

# %%
listingdf = df

# %%
listingdf = listingdf.drop('listing_url', axis = 1)
listingdf = listingdf.drop('scrape_id', axis = 1)
listingdf = listingdf.drop('last_scraped', axis = 1)
listingdf = listingdf.drop('name', axis = 1)
listingdf = listingdf.drop('summary', axis = 1)
listingdf = listingdf.drop('space', axis = 1)
listingdf = listingdf.drop('description', axis = 1)
listingdf = listingdf.drop('experiences_offered', axis = 1)
listingdf = listingdf.drop('neighborhood_overview', axis = 1)
listingdf = listingdf.drop('notes', axis = 1)
listingdf = listingdf.drop('transit', axis = 1)
listingdf = listingdf.drop('thumbnail_url', axis = 1)
listingdf = listingdf.drop('medium_url', axis = 1)
listingdf = listingdf.drop('picture_url', axis = 1)
listingdf = listingdf.drop('xl_picture_url', axis = 1)
listingdf = listingdf.drop('host_id', axis = 1)
listingdf = listingdf.drop('host_url', axis = 1)
listingdf = listingdf.drop('host_name', axis = 1)
listingdf = listingdf.drop('host_since', axis = 1)
listingdf = listingdf.drop('host_location', axis = 1)
listingdf = listingdf.drop('host_about', axis = 1)
#listingdf = listingdf.drop('host_response_time, axis = 1) #maybe
listingdf = listingdf.drop('host_thumbnail_url', axis = 1)
listingdf = listingdf.drop('street', axis = 1)
listingdf = listingdf.drop('host_picture_url', axis = 1)
listingdf = listingdf.drop('host_neighbourhood', axis = 1)
listingdf = listingdf.drop('host_listings_count', axis = 1)
listingdf = listingdf.drop('host_total_listings_count', axis = 1)
listingdf = listingdf.drop('host_verifications', axis = 1)
listingdf = listingdf.drop('host_has_profile_pic', axis = 1)
listingdf = listingdf.drop('host_identity_verified', axis = 1)
listingdf = listingdf.drop('neighbourhood', axis = 1)
listingdf = listingdf.drop('neighbourhood_group_cleansed', axis = 1)
listingdf = listingdf.drop('city', axis = 1)
listingdf = listingdf.drop('state', axis = 1)
listingdf = listingdf.drop('market', axis = 1)
listingdf = listingdf.drop('country', axis = 1)
listingdf = listingdf.drop('latitude', axis = 1)
listingdf = listingdf.drop('longitude', axis = 1)
listingdf = listingdf.drop('is_location_exact', axis = 1)
listingdf = listingdf.drop('square_feet', axis = 1)
listingdf = listingdf.drop('weekly_price', axis = 1)
listingdf = listingdf.drop('monthly_price', axis = 1)
listingdf = listingdf.drop('security_deposit', axis = 1)
listingdf = listingdf.drop('calendar_updated', axis = 1)
listingdf = listingdf.drop('has_availability', axis = 1)
listingdf = listingdf.drop('availability_30', axis = 1)
listingdf = listingdf.drop('availability_60', axis = 1)
listingdf = listingdf.drop('availability_90', axis = 1)
listingdf = listingdf.drop('availability_365', axis = 1)
listingdf = listingdf.drop('calendar_last_scraped', axis = 1)
listingdf = listingdf.drop('first_review', axis = 1)
listingdf = listingdf.drop('last_review', axis = 1)
listingdf = listingdf.drop('requires_license', axis = 1)
listingdf = listingdf.drop('license', axis = 1)
listingdf = listingdf.drop('jurisdiction_names', axis = 1)
listingdf = listingdf.drop('require_guest_profile_picture', axis = 1)
listingdf = listingdf.drop('require_guest_phone_verification', axis = 1)
listingdf = listingdf.drop('calculated_host_listings_count', axis = 1)
listingdf = listingdf.drop('reviews_per_month', axis = 1)
listingdf = listingdf.drop('smart_location', axis = 1) # maybe
listingdf = listingdf.drop('zipcode', axis = 1) # maybe
listingdf = listingdf.drop('country_code', axis = 1) # maybe
listingdf = listingdf.drop('amenities', axis = 1) # to be added later

listingdf = listingdf.drop('extra_people', axis = 1) # to be added later
listingdf = listingdf.drop('id', axis = 1)

# %%
listingdf.head()
# Out:
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  within a few hours                96%                 100%
# 1      within an hour                98%                 100%
# 2  within a few hours                67%                 100%
# 3                 NaN                NaN                  NaN
# 4      within an hour               100%                  NaN
#
#   host_is_superhost neighbourhood_cleansed property_type        room_type  \
# 0                 f        West Queen Anne     Apartment  Entire home/apt
# 1                 t        West Queen Anne     Apartment  Entire home/apt
# 2                 f        West Queen Anne         House  Entire home/apt
# 3                 f        West Queen Anne     Apartment  Entire home/apt
# 4                 f        West Queen Anne         House  Entire home/apt
#
#    accommodates  bathrooms  bedrooms         ...           number_of_reviews  \
# 0             4        1.0       1.0         ...                         207
# 1             4        1.0       1.0         ...                          43
# 2            11        4.5       5.0         ...                          20
# 3             3        1.0       0.0         ...                           0
# 4             6        2.0       3.0         ...                          38
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 95.0                   10.0                      10.0
# 1                 96.0                   10.0                      10.0
# 2                 97.0                   10.0                      10.0
# 3                  NaN                    NaN                       NaN
# 4                 92.0                    9.0                       9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                     9.0
# 1                   10.0                         10.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                    NaN                          NaN                     NaN
# 4                   10.0                         10.0                     9.0
#
#    review_scores_value  instant_bookable  cancellation_policy
# 0                 10.0                 f             moderate
# 1                 10.0                 f               strict
# 2                 10.0                 f               strict
# 3                  NaN                 f             flexible
# 4                  9.0                 f               strict
#
# [5 rows x 27 columns]

# %%
listingdf = listingdf.dropna()

# %%
listingdf['host_response_rate'] = listingdf['host_response_rate'].str.replace('%','')
listingdf['host_response_rate'] = listingdf['host_response_rate'].astype('float')

listingdf['host_acceptance_rate'] = listingdf['host_acceptance_rate'].str.replace('%','')
listingdf['host_acceptance_rate'] = listingdf['host_acceptance_rate'].astype('float')

listingdf['price'] = listingdf['price'].str.replace('$','')
listingdf['price'] = listingdf['price'].astype('float')

listingdf['cleaning_fee'] = listingdf['cleaning_fee'].str.replace('$','')
listingdf['cleaning_fee'] = listingdf['cleaning_fee'].astype('float')

# %%
listingdf = pd.get_dummies(listingdf, columns=['instant_bookable', 'bed_type', 'room_type','property_type', 'neighbourhood_cleansed','host_is_superhost', 'neighbourhood_cleansed', 'host_response_time', 'cancellation_policy'])

# %%
listingdf = listingdf.reset_index(drop=True)

# %%
# View the correlations

listingdf.corr()
# Out:
#                                             host_response_rate  \
# host_response_rate                                    1.000000
# host_acceptance_rate                                 -0.009560
# accommodates                                          0.007824
# bathrooms                                             0.003128
# bedrooms                                             -0.002636
# beds                                                  0.007934
# price                                                -0.028064
# cleaning_fee                                         -0.057630
# guests_included                                       0.060826
# minimum_nights                                        0.006647
# maximum_nights                                       -0.093712
# number_of_reviews                                     0.110252
# review_scores_rating                                  0.141699
# review_scores_accuracy                                0.112988
# review_scores_cleanliness                             0.136831
# review_scores_checkin                                 0.137698
# review_scores_communication                           0.146717
# review_scores_location                                0.060773
# review_scores_value                                   0.114653
# instant_bookable_f                                   -0.119632
# instant_bookable_t                                    0.119632
# bed_type_Airbed                                       0.007543
# bed_type_Couch                                        0.005570
# bed_type_Futon                                       -0.001533
# bed_type_Pull-out Sofa                                0.011928
# bed_type_Real Bed                                    -0.010856
# room_type_Entire home/apt                             0.000915
# room_type_Private room                                0.020479
# room_type_Shared room                                -0.059490
# property_type_Apartment                              -0.044729
# ...                                                        ...
# neighbourhood_cleansed_Ravenna                       -0.008053
# neighbourhood_cleansed_Riverview                      0.016567
# neighbourhood_cleansed_Roosevelt                      0.003386
# neighbourhood_cleansed_Seaview                       -0.017862
# neighbourhood_cleansed_Seward Park                   -0.015325
# neighbourhood_cleansed_South Beacon Hill              0.009035
# neighbourhood_cleansed_South Delridge                 0.021398
# neighbourhood_cleansed_South Lake Union              -0.034440
# neighbourhood_cleansed_South Park                     0.009560
# neighbourhood_cleansed_Southeast Magnolia             0.017433
# neighbourhood_cleansed_Stevens                        0.002770
# neighbourhood_cleansed_Sunset Hill                   -0.071661
# neighbourhood_cleansed_University District           -0.107782
# neighbourhood_cleansed_Victory Heights                0.011929
# neighbourhood_cleansed_View Ridge                    -0.007870
# neighbourhood_cleansed_Wallingford                   -0.028251
# neighbourhood_cleansed_Wedgwood                      -0.025947
# neighbourhood_cleansed_West Queen Anne               -0.005341
# neighbourhood_cleansed_West Woodland                  0.045334
# neighbourhood_cleansed_Westlake                      -0.088512
# neighbourhood_cleansed_Whittier Heights               0.032720
# neighbourhood_cleansed_Windermere                     0.019134
# neighbourhood_cleansed_Yesler Terrace                -0.045443
# host_response_time_a few days or more                -0.522945
# host_response_time_within a day                      -0.348042
# host_response_time_within a few hours                -0.002785
# host_response_time_within an hour                     0.335559
# cancellation_policy_flexible                         -0.070824
# cancellation_policy_moderate                          0.028530
# cancellation_policy_strict                            0.026525
#
#                                             host_acceptance_rate  \
# host_response_rate                                     -0.009560
# host_acceptance_rate                                    1.000000
# accommodates                                            0.017525
# bathrooms                                               0.010376
# bedrooms                                                0.008363
# beds                                                    0.015648
# price                                                   0.008931
# cleaning_fee                                            0.018437
# guests_included                                         0.013200
# minimum_nights                                         -0.000447
# maximum_nights                                         -0.017245
# number_of_reviews                                       0.012579
# review_scores_rating                                   -0.018580
# review_scores_accuracy                                  0.019327
# review_scores_cleanliness                              -0.012132
# review_scores_checkin                                  -0.007853
# review_scores_communication                            -0.007763
# review_scores_location                                 -0.013395
# review_scores_value                                     0.013024
# instant_bookable_f                                      0.044162
# instant_bookable_t                                     -0.044162
# bed_type_Airbed                                         0.001473
# bed_type_Couch                                          0.000849
# bed_type_Futon                                          0.002414
# bed_type_Pull-out Sofa                                 -0.202971
# bed_type_Real Bed                                       0.127220
# room_type_Entire home/apt                               0.037292
# room_type_Private room                                  0.012321
# room_type_Shared room                                  -0.141167
# property_type_Apartment                                -0.023662
# ...                                                          ...
# neighbourhood_cleansed_Ravenna                          0.003048
# neighbourhood_cleansed_Riverview                        0.000849
# neighbourhood_cleansed_Roosevelt                        0.001772
# neighbourhood_cleansed_Seaview                          0.001388
# neighbourhood_cleansed_Seward Park                      0.002464
# neighbourhood_cleansed_South Beacon Hill                0.000693
# neighbourhood_cleansed_South Delridge                   0.001097
# neighbourhood_cleansed_South Lake Union                 0.001839
# neighbourhood_cleansed_South Park                       0.000490
# neighbourhood_cleansed_Southeast Magnolia               0.001473
# neighbourhood_cleansed_Stevens                          0.003168
# neighbourhood_cleansed_Sunset Hill                      0.001202
# neighbourhood_cleansed_University District              0.004139
# neighbourhood_cleansed_Victory Heights                  0.001097
# neighbourhood_cleansed_View Ridge                       0.000849
# neighbourhood_cleansed_Wallingford                      0.005179
# neighbourhood_cleansed_Wedgwood                         0.001097
# neighbourhood_cleansed_West Queen Anne                  0.002923
# neighbourhood_cleansed_West Woodland                    0.002837
# neighbourhood_cleansed_Westlake                         0.000849
# neighbourhood_cleansed_Whittier Heights                 0.002087
# neighbourhood_cleansed_Windermere                       0.000981
# neighbourhood_cleansed_Yesler Terrace                   0.001473
# host_response_time_a few days or more                   0.001904
# host_response_time_within a day                        -0.055072
# host_response_time_within a few hours                   0.014093
# host_response_time_within an hour                       0.025233
# cancellation_policy_flexible                            0.010154
# cancellation_policy_moderate                           -0.030285
# cancellation_policy_strict                              0.021180
#
#                                             accommodates  bathrooms  bedrooms  \
# host_response_rate                              0.007824   0.003128 -0.002636
# host_acceptance_rate                            0.017525   0.010376  0.008363
# accommodates                                    1.000000   0.588158  0.776129
# bathrooms                                       0.588158   1.000000  0.665838
# bedrooms                                        0.776129   0.665838  1.000000
# beds                                            0.863926   0.566883  0.754958
# price                                           0.662136   0.589560  0.643387
# cleaning_fee                                    0.672942   0.540392  0.627687
# guests_included                                 0.538664   0.335815  0.474650
# minimum_nights                                  0.008487  -0.002668  0.000928
# maximum_nights                                  0.025940  -0.000066  0.005307
# number_of_reviews                              -0.103328  -0.118102 -0.114265
# review_scores_rating                           -0.022777   0.047569  0.010795
# review_scores_accuracy                         -0.054372  -0.020684 -0.017587
# review_scores_cleanliness                      -0.010025   0.010127 -0.037335
# review_scores_checkin                          -0.031386  -0.003620 -0.002383
# review_scores_communication                    -0.020953  -0.019769 -0.007318
# review_scores_location                         -0.050160  -0.004441 -0.028360
# review_scores_value                            -0.066226   0.001995 -0.014428
# instant_bookable_f                             -0.006530   0.049632  0.076514
# instant_bookable_t                              0.006530  -0.049632 -0.076514
# bed_type_Airbed                                -0.038516   0.007235 -0.008889
# bed_type_Couch                                 -0.042614  -0.017981 -0.014492
# bed_type_Futon                                 -0.084164  -0.039313 -0.061178
# bed_type_Pull-out Sofa                         -0.058053  -0.031441 -0.066172
# bed_type_Real Bed                               0.115532   0.046393  0.088045
# room_type_Entire home/apt                       0.439479   0.113939  0.224258
# room_type_Private room                         -0.397632  -0.084226 -0.210296
# room_type_Shared room                          -0.156321  -0.092909 -0.059241
# property_type_Apartment                        -0.106037  -0.245499 -0.274686
# ...                                                  ...        ...       ...
# neighbourhood_cleansed_Ravenna                 -0.022255  -0.008046 -0.000254
# neighbourhood_cleansed_Riverview               -0.018123  -0.006905 -0.000440
# neighbourhood_cleansed_Roosevelt               -0.004401  -0.016187  0.003592
# neighbourhood_cleansed_Seaview                  0.006659  -0.015817  0.010767
# neighbourhood_cleansed_Seward Park             -0.000708  -0.017470  0.001984
# neighbourhood_cleansed_South Beacon Hill        0.020193  -0.014678  0.022581
# neighbourhood_cleansed_South Delridge          -0.001264  -0.023225 -0.007829
# neighbourhood_cleansed_South Lake Union        -0.031677  -0.018384 -0.031391
# neighbourhood_cleansed_South Park               0.003675  -0.010376  0.015963
# neighbourhood_cleansed_Southeast Magnolia       0.011047   0.020044  0.007361
# neighbourhood_cleansed_Stevens                 -0.013015   0.020607 -0.008038
# neighbourhood_cleansed_Sunset Hill              0.039342   0.107795  0.088867
# neighbourhood_cleansed_University District     -0.024759  -0.024273 -0.043847
# neighbourhood_cleansed_Victory Heights         -0.029734  -0.023225 -0.018718
# neighbourhood_cleansed_View Ridge               0.030860   0.004171  0.027663
# neighbourhood_cleansed_Wallingford             -0.028804  -0.037023 -0.001069
# neighbourhood_cleansed_Wedgwood                -0.024989   0.002526  0.003061
# neighbourhood_cleansed_West Queen Anne          0.025540   0.032882  0.028892
# neighbourhood_cleansed_West Woodland            0.026859  -0.012978  0.002797
# neighbourhood_cleansed_Westlake                 0.018614   0.048476  0.027663
# neighbourhood_cleansed_Whittier Heights        -0.009431  -0.007899  0.010433
# neighbourhood_cleansed_Windermere               0.028571   0.027205  0.044123
# neighbourhood_cleansed_Yesler Terrace          -0.003114  -0.018382 -0.025138
# host_response_time_a few days or more          -0.018673  -0.010518 -0.007290
# host_response_time_within a day                 0.052502   0.028587  0.064339
# host_response_time_within a few hours           0.035830   0.064866  0.057633
# host_response_time_within an hour              -0.066174  -0.077421 -0.096322
# cancellation_policy_flexible                   -0.157123  -0.047131 -0.120771
# cancellation_policy_moderate                   -0.158255  -0.116432 -0.128143
# cancellation_policy_strict                      0.270139   0.146801  0.213841
#
#                                                 beds     price  cleaning_fee  \
# host_response_rate                          0.007934 -0.028064     -0.057630
# host_acceptance_rate                        0.015648  0.008931      0.018437
# accommodates                                0.863926  0.662136      0.672942
# bathrooms                                   0.566883  0.589560      0.540392
# bedrooms                                    0.754958  0.643387      0.627687
# beds                                        1.000000  0.609165      0.642882
# price                                       0.609165  1.000000      0.672466
# cleaning_fee                                0.642882  0.672466      1.000000
# guests_included                             0.467802  0.426220      0.344320
# minimum_nights                             -0.010407  0.016511      0.019094
# maximum_nights                              0.019655  0.000067      0.029633
# number_of_reviews                          -0.114299 -0.127473     -0.188335
# review_scores_rating                       -0.006523  0.068983     -0.013965
# review_scores_accuracy                     -0.055270  0.013575     -0.039740
# review_scores_cleanliness                  -0.007315  0.054973      0.041349
# review_scores_checkin                      -0.024175  0.005873     -0.081175
# review_scores_communication                -0.013707  0.008007     -0.062849
# review_scores_location                     -0.030808  0.092367     -0.002792
# review_scores_value                        -0.034419 -0.039188     -0.087771
# instant_bookable_f                         -0.020850  0.054176      0.042756
# instant_bookable_t                          0.020850 -0.054176     -0.042756
# bed_type_Airbed                            -0.035031 -0.039161     -0.040005
# bed_type_Couch                             -0.027116 -0.041623     -0.042347
# bed_type_Futon                             -0.069715 -0.064623     -0.077572
# bed_type_Pull-out Sofa                     -0.047580 -0.053660     -0.057675
# bed_type_Real Bed                           0.094745  0.100286      0.111608
# room_type_Entire home/apt                   0.330832  0.420214      0.430337
# room_type_Private room                     -0.313017 -0.380794     -0.403913
# room_type_Shared room                      -0.079669 -0.147819     -0.112657
# property_type_Apartment                    -0.156835 -0.042633     -0.030796
# ...                                              ...       ...           ...
# neighbourhood_cleansed_Ravenna             -0.006141 -0.056021     -0.057651
# neighbourhood_cleansed_Riverview           -0.016735 -0.019884     -0.021286
# neighbourhood_cleansed_Roosevelt            0.003403 -0.027205     -0.016088
# neighbourhood_cleansed_Seaview              0.000218  0.001172      0.002521
# neighbourhood_cleansed_Seward Park          0.004455 -0.036583     -0.020305
# neighbourhood_cleansed_South Beacon Hill    0.003287 -0.004541     -0.003230
# neighbourhood_cleansed_South Delridge      -0.010889 -0.030805     -0.018127
# neighbourhood_cleansed_South Lake Union    -0.049099  0.020472     -0.035176
# neighbourhood_cleansed_South Park           0.020295 -0.006389      0.000024
# neighbourhood_cleansed_Southeast Magnolia   0.000982  0.028017     -0.005476
# neighbourhood_cleansed_Stevens              0.000852  0.002284     -0.004210
# neighbourhood_cleansed_Sunset Hill          0.042427  0.116335      0.067975
# neighbourhood_cleansed_University District -0.017778 -0.062069     -0.000246
# neighbourhood_cleansed_Victory Heights     -0.018934 -0.032854     -0.019573
# neighbourhood_cleansed_View Ridge           0.024788  0.002883      0.005374
# neighbourhood_cleansed_Wallingford         -0.005907 -0.042175     -0.033205
# neighbourhood_cleansed_Wedgwood            -0.010889 -0.027048     -0.016474
# neighbourhood_cleansed_West Queen Anne      0.050621  0.071158      0.056239
# neighbourhood_cleansed_West Woodland        0.016606 -0.005759     -0.020914
# neighbourhood_cleansed_Westlake             0.035168  0.091161     -0.003957
# neighbourhood_cleansed_Whittier Heights     0.005645 -0.002361     -0.000442
# neighbourhood_cleansed_Windermere           0.031627  0.027929      0.036999
# neighbourhood_cleansed_Yesler Terrace      -0.017025 -0.000349     -0.029986
# host_response_time_a few days or more      -0.032876  0.020895     -0.002297
# host_response_time_within a day             0.028400  0.054497      0.113140
# host_response_time_within a few hours       0.039623  0.083639      0.024729
# host_response_time_within an hour          -0.050371 -0.118073     -0.101176
# cancellation_policy_flexible               -0.123905 -0.132397     -0.218682
# cancellation_policy_moderate               -0.140276 -0.152276     -0.184235
# cancellation_policy_strict                  0.227790  0.245678      0.341622
#
#                                             guests_included  minimum_nights  \
# host_response_rate                                 0.060826        0.006647
# host_acceptance_rate                               0.013200       -0.000447
# accommodates                                       0.538664        0.008487
# bathrooms                                          0.335815       -0.002668
# bedrooms                                           0.474650        0.000928
# beds                                               0.467802       -0.010407
# price                                              0.426220        0.016511
# cleaning_fee                                       0.344320        0.019094
# guests_included                                    1.000000       -0.008992
# minimum_nights                                    -0.008992        1.000000
# maximum_nights                                    -0.051294        0.014069
# number_of_reviews                                  0.021450       -0.015689
# review_scores_rating                               0.001140       -0.002040
# review_scores_accuracy                             0.014462       -0.018812
# review_scores_cleanliness                          0.008236       -0.049392
# review_scores_checkin                              0.043556       -0.027286
# review_scores_communication                        0.024420        0.008514
# review_scores_location                            -0.029010        0.016650
# review_scores_value                               -0.007775       -0.011771
# instant_bookable_f                                 0.013390        0.017511
# instant_bookable_t                                -0.013390       -0.017511
# bed_type_Airbed                                    0.002562       -0.003660
# bed_type_Couch                                    -0.022874       -0.002110
# bed_type_Futon                                    -0.035825       -0.004973
# bed_type_Pull-out Sofa                            -0.045561        0.000357
# bed_type_Real Bed                                  0.056121        0.004860
# room_type_Entire home/apt                          0.250368        0.019877
# room_type_Private room                            -0.227395       -0.021099
# room_type_Shared room                             -0.086647        0.001578
# property_type_Apartment                           -0.157543        0.025092
# ...                                                     ...             ...
# neighbourhood_cleansed_Ravenna                     0.011054        0.000655
# neighbourhood_cleansed_Riverview                   0.004521       -0.000956
# neighbourhood_cleansed_Roosevelt                   0.018229       -0.002551
# neighbourhood_cleansed_Seaview                    -0.015003       -0.002624
# neighbourhood_cleansed_Seward Park                -0.018683       -0.003377
# neighbourhood_cleansed_South Beacon Hill           0.048415       -0.002193
# neighbourhood_cleansed_South Delridge             -0.001237       -0.001682
# neighbourhood_cleansed_South Lake Union           -0.036831        0.004355
# neighbourhood_cleansed_South Park                  0.002609       -0.000552
# neighbourhood_cleansed_Southeast Magnolia          0.007842       -0.001992
# neighbourhood_cleansed_Stevens                     0.014378       -0.000575
# neighbourhood_cleansed_Sunset Hill                 0.045169        0.000688
# neighbourhood_cleansed_University District        -0.057320       -0.006006
# neighbourhood_cleansed_Victory Heights             0.012916       -0.002576
# neighbourhood_cleansed_View Ridge                  0.022784        0.000198
# neighbourhood_cleansed_Wallingford                 0.007084       -0.002047
# neighbourhood_cleansed_Wedgwood                   -0.022467        0.000553
# neighbourhood_cleansed_West Queen Anne             0.045206       -0.001419
# neighbourhood_cleansed_West Woodland               0.062260        0.003289
# neighbourhood_cleansed_Westlake                    0.031916       -0.000379
# neighbourhood_cleansed_Whittier Heights           -0.015077       -0.004005
# neighbourhood_cleansed_Windermere                 -0.018509       -0.001104
# neighbourhood_cleansed_Yesler Terrace              0.002562       -0.003993
# host_response_time_a few days or more             -0.030819        0.003548
# host_response_time_within a day                   -0.035508       -0.007272
# host_response_time_within a few hours              0.028723        0.033780
# host_response_time_within an hour                  0.003845       -0.026406
# cancellation_policy_flexible                      -0.124046       -0.019478
# cancellation_policy_moderate                      -0.079040        0.028581
# cancellation_policy_strict                         0.169495       -0.012480
#
#                                                        ...              \
# host_response_rate                                     ...
# host_acceptance_rate                                   ...
# accommodates                                           ...
# bathrooms                                              ...
# bedrooms                                               ...
# beds                                                   ...
# price                                                  ...
# cleaning_fee                                           ...
# guests_included                                        ...
# minimum_nights                                         ...
# maximum_nights                                         ...
# number_of_reviews                                      ...
# review_scores_rating                                   ...
# review_scores_accuracy                                 ...
# review_scores_cleanliness                              ...
# review_scores_checkin                                  ...
# review_scores_communication                            ...
# review_scores_location                                 ...
# review_scores_value                                    ...
# instant_bookable_f                                     ...
# instant_bookable_t                                     ...
# bed_type_Airbed                                        ...
# bed_type_Couch                                         ...
# bed_type_Futon                                         ...
# bed_type_Pull-out Sofa                                 ...
# bed_type_Real Bed                                      ...
# room_type_Entire home/apt                              ...
# room_type_Private room                                 ...
# room_type_Shared room                                  ...
# property_type_Apartment                                ...
# ...                                                    ...
# neighbourhood_cleansed_Ravenna                         ...
# neighbourhood_cleansed_Riverview                       ...
# neighbourhood_cleansed_Roosevelt                       ...
# neighbourhood_cleansed_Seaview                         ...
# neighbourhood_cleansed_Seward Park                     ...
# neighbourhood_cleansed_South Beacon Hill               ...
# neighbourhood_cleansed_South Delridge                  ...
# neighbourhood_cleansed_South Lake Union                ...
# neighbourhood_cleansed_South Park                      ...
# neighbourhood_cleansed_Southeast Magnolia              ...
# neighbourhood_cleansed_Stevens                         ...
# neighbourhood_cleansed_Sunset Hill                     ...
# neighbourhood_cleansed_University District             ...
# neighbourhood_cleansed_Victory Heights                 ...
# neighbourhood_cleansed_View Ridge                      ...
# neighbourhood_cleansed_Wallingford                     ...
# neighbourhood_cleansed_Wedgwood                        ...
# neighbourhood_cleansed_West Queen Anne                 ...
# neighbourhood_cleansed_West Woodland                   ...
# neighbourhood_cleansed_Westlake                        ...
# neighbourhood_cleansed_Whittier Heights                ...
# neighbourhood_cleansed_Windermere                      ...
# neighbourhood_cleansed_Yesler Terrace                  ...
# host_response_time_a few days or more                  ...
# host_response_time_within a day                        ...
# host_response_time_within a few hours                  ...
# host_response_time_within an hour                      ...
# cancellation_policy_flexible                           ...
# cancellation_policy_moderate                           ...
# cancellation_policy_strict                             ...
#
#                                             neighbourhood_cleansed_Whittier Heights  \
# host_response_rate                                                         0.032720
# host_acceptance_rate                                                       0.002087
# accommodates                                                              -0.009431
# bathrooms                                                                 -0.007899
# bedrooms                                                                   0.010433
# beds                                                                       0.005645
# price                                                                     -0.002361
# cleaning_fee                                                              -0.000442
# guests_included                                                           -0.015077
# minimum_nights                                                            -0.004005
# maximum_nights                                                            -0.043221
# number_of_reviews                                                          0.050415
# review_scores_rating                                                       0.028464
# review_scores_accuracy                                                     0.020714
# review_scores_cleanliness                                                  0.044648
# review_scores_checkin                                                      0.033458
# review_scores_communication                                                0.024118
# review_scores_location                                                     0.031713
# review_scores_value                                                        0.042540
# instant_bookable_f                                                        -0.070440
# instant_bookable_t                                                         0.070440
# bed_type_Airbed                                                           -0.006275
# bed_type_Couch                                                            -0.003617
# bed_type_Futon                                                            -0.010284
# bed_type_Pull-out Sofa                                                    -0.010284
# bed_type_Real Bed                                                          0.016408
# room_type_Entire home/apt                                                  0.008230
# room_type_Private room                                                    -0.003176
# room_type_Shared room                                                     -0.014787
# property_type_Apartment                                                   -0.046213
# ...                                                                             ...
# neighbourhood_cleansed_Ravenna                                            -0.012986
# neighbourhood_cleansed_Riverview                                          -0.003617
# neighbourhood_cleansed_Roosevelt                                          -0.007549
# neighbourhood_cleansed_Seaview                                            -0.005914
# neighbourhood_cleansed_Seward Park                                        -0.010499
# neighbourhood_cleansed_South Beacon Hill                                  -0.002953
# neighbourhood_cleansed_South Delridge                                     -0.004672
# neighbourhood_cleansed_South Lake Union                                   -0.007835
# neighbourhood_cleansed_South Park                                         -0.002087
# neighbourhood_cleansed_Southeast Magnolia                                 -0.006275
# neighbourhood_cleansed_Stevens                                            -0.013499
# neighbourhood_cleansed_Sunset Hill                                        -0.005119
# neighbourhood_cleansed_University District                                -0.017636
# neighbourhood_cleansed_Victory Heights                                    -0.004672
# neighbourhood_cleansed_View Ridge                                         -0.003617
# neighbourhood_cleansed_Wallingford                                        -0.022066
# neighbourhood_cleansed_Wedgwood                                           -0.004672
# neighbourhood_cleansed_West Queen Anne                                    -0.012453
# neighbourhood_cleansed_West Woodland                                      -0.012086
# neighbourhood_cleansed_Westlake                                           -0.003617
# neighbourhood_cleansed_Whittier Heights                                    1.000000
# neighbourhood_cleansed_Windermere                                         -0.004178
# neighbourhood_cleansed_Yesler Terrace                                     -0.006275
# host_response_time_a few days or more                                     -0.008112
# host_response_time_within a day                                           -0.022763
# host_response_time_within a few hours                                     -0.002220
# host_response_time_within an hour                                          0.019315
# cancellation_policy_flexible                                              -0.001787
# cancellation_policy_moderate                                               0.041049
# cancellation_policy_strict                                                -0.037793
#
#                                             neighbourhood_cleansed_Windermere  \
# host_response_rate                                                   0.019134
# host_acceptance_rate                                                 0.000981
# accommodates                                                         0.028571
# bathrooms                                                            0.027205
# bedrooms                                                             0.044123
# beds                                                                 0.031627
# price                                                                0.027929
# cleaning_fee                                                         0.036999
# guests_included                                                     -0.018509
# minimum_nights                                                      -0.001104
# maximum_nights                                                       0.017901
# number_of_reviews                                                   -0.012447
# review_scores_rating                                                 0.008269
# review_scores_accuracy                                               0.008002
# review_scores_cleanliness                                           -0.020361
# review_scores_checkin                                               -0.001613
# review_scores_communication                                         -0.003393
# review_scores_location                                               0.008942
# review_scores_value                                                  0.018340
# instant_bookable_f                                                   0.022205
# instant_bookable_t                                                  -0.022205
# bed_type_Airbed                                                     -0.002948
# bed_type_Couch                                                      -0.001699
# bed_type_Futon                                                      -0.004831
# bed_type_Pull-out Sofa                                              -0.004831
# bed_type_Real Bed                                                    0.007708
# room_type_Entire home/apt                                            0.026296
# room_type_Private room                                              -0.024659
# room_type_Shared room                                               -0.006947
# property_type_Apartment                                             -0.019243
# ...                                                                       ...
# neighbourhood_cleansed_Ravenna                                      -0.006101
# neighbourhood_cleansed_Riverview                                    -0.001699
# neighbourhood_cleansed_Roosevelt                                    -0.003546
# neighbourhood_cleansed_Seaview                                      -0.002778
# neighbourhood_cleansed_Seward Park                                  -0.004932
# neighbourhood_cleansed_South Beacon Hill                            -0.001387
# neighbourhood_cleansed_South Delridge                               -0.002195
# neighbourhood_cleansed_South Lake Union                             -0.003681
# neighbourhood_cleansed_South Park                                   -0.000981
# neighbourhood_cleansed_Southeast Magnolia                           -0.002948
# neighbourhood_cleansed_Stevens                                      -0.006342
# neighbourhood_cleansed_Sunset Hill                                  -0.002405
# neighbourhood_cleansed_University District                          -0.008285
# neighbourhood_cleansed_Victory Heights                              -0.002195
# neighbourhood_cleansed_View Ridge                                   -0.001699
# neighbourhood_cleansed_Wallingford                                  -0.010366
# neighbourhood_cleansed_Wedgwood                                     -0.002195
# neighbourhood_cleansed_West Queen Anne                              -0.005850
# neighbourhood_cleansed_West Woodland                                -0.005678
# neighbourhood_cleansed_Westlake                                     -0.001699
# neighbourhood_cleansed_Whittier Heights                             -0.004178
# neighbourhood_cleansed_Windermere                                    1.000000
# neighbourhood_cleansed_Yesler Terrace                               -0.002948
# host_response_time_a few days or more                               -0.003811
# host_response_time_within a day                                     -0.017806
# host_response_time_within a few hours                                0.045136
# host_response_time_within an hour                                   -0.028162
# cancellation_policy_flexible                                        -0.020323
# cancellation_policy_moderate                                         0.014118
# cancellation_policy_strict                                           0.001955
#
#                                             neighbourhood_cleansed_Yesler Terrace  \
# host_response_rate                                                      -0.045443
# host_acceptance_rate                                                     0.001473
# accommodates                                                            -0.003114
# bathrooms                                                               -0.018382
# bedrooms                                                                -0.025138
# beds                                                                    -0.017025
# price                                                                   -0.000349
# cleaning_fee                                                            -0.029986
# guests_included                                                          0.002562
# minimum_nights                                                          -0.003993
# maximum_nights                                                           0.024768
# number_of_reviews                                                       -0.035109
# review_scores_rating                                                     0.018379
# review_scores_accuracy                                                   0.014614
# review_scores_cleanliness                                               -0.033062
# review_scores_checkin                                                    0.023606
# review_scores_communication                                              0.023334
# review_scores_location                                                  -0.007441
# review_scores_value                                                      0.000373
# instant_bookable_f                                                      -0.003561
# instant_bookable_t                                                       0.003561
# bed_type_Airbed                                                         -0.004427
# bed_type_Couch                                                          -0.002552
# bed_type_Futon                                                          -0.007256
# bed_type_Pull-out Sofa                                                  -0.007256
# bed_type_Real Bed                                                        0.011576
# room_type_Entire home/apt                                                0.005807
# room_type_Private room                                                  -0.002241
# room_type_Shared room                                                   -0.010433
# property_type_Apartment                                                  0.056306
# ...                                                                           ...
# neighbourhood_cleansed_Ravenna                                          -0.009162
# neighbourhood_cleansed_Riverview                                        -0.002552
# neighbourhood_cleansed_Roosevelt                                        -0.005326
# neighbourhood_cleansed_Seaview                                          -0.004173
# neighbourhood_cleansed_Seward Park                                      -0.007407
# neighbourhood_cleansed_South Beacon Hill                                -0.002083
# neighbourhood_cleansed_South Delridge                                   -0.003296
# neighbourhood_cleansed_South Lake Union                                 -0.005528
# neighbourhood_cleansed_South Park                                       -0.001473
# neighbourhood_cleansed_Southeast Magnolia                               -0.004427
# neighbourhood_cleansed_Stevens                                          -0.009524
# neighbourhood_cleansed_Sunset Hill                                      -0.003612
# neighbourhood_cleansed_University District                              -0.012443
# neighbourhood_cleansed_Victory Heights                                  -0.003296
# neighbourhood_cleansed_View Ridge                                       -0.002552
# neighbourhood_cleansed_Wallingford                                      -0.015569
# neighbourhood_cleansed_Wedgwood                                         -0.003296
# neighbourhood_cleansed_West Queen Anne                                  -0.008786
# neighbourhood_cleansed_West Woodland                                    -0.008527
# neighbourhood_cleansed_Westlake                                         -0.002552
# neighbourhood_cleansed_Whittier Heights                                 -0.006275
# neighbourhood_cleansed_Windermere                                       -0.002948
# neighbourhood_cleansed_Yesler Terrace                                    1.000000
# host_response_time_a few days or more                                    0.080852
# host_response_time_within a day                                          0.015987
# host_response_time_within a few hours                                   -0.042362
# host_response_time_within an hour                                        0.013627
# cancellation_policy_flexible                                             0.047507
# cancellation_policy_moderate                                            -0.033111
# cancellation_policy_strict                                              -0.004465
#
#                                             host_response_time_a few days or more  \
# host_response_rate                                                      -0.522945
# host_acceptance_rate                                                     0.001904
# accommodates                                                            -0.018673
# bathrooms                                                               -0.010518
# bedrooms                                                                -0.007290
# beds                                                                    -0.032876
# price                                                                    0.020895
# cleaning_fee                                                            -0.002297
# guests_included                                                         -0.030819
# minimum_nights                                                           0.003548
# maximum_nights                                                           0.044244
# number_of_reviews                                                       -0.033458
# review_scores_rating                                                    -0.029086
# review_scores_accuracy                                                  -0.010650
# review_scores_cleanliness                                               -0.053020
# review_scores_checkin                                                   -0.014348
# review_scores_communication                                             -0.038444
# review_scores_location                                                   0.015051
# review_scores_value                                                     -0.012293
# instant_bookable_f                                                       0.028801
# instant_bookable_t                                                      -0.028801
# bed_type_Airbed                                                         -0.005724
# bed_type_Couch                                                          -0.003300
# bed_type_Futon                                                           0.043832
# bed_type_Pull-out Sofa                                                  -0.009381
# bed_type_Real Bed                                                       -0.018992
# room_type_Entire home/apt                                               -0.014269
# room_type_Private room                                                   0.006100
# room_type_Shared room                                                    0.023986
# property_type_Apartment                                                  0.022985
# ...                                                                           ...
# neighbourhood_cleansed_Ravenna                                          -0.011846
# neighbourhood_cleansed_Riverview                                        -0.003300
# neighbourhood_cleansed_Roosevelt                                        -0.006886
# neighbourhood_cleansed_Seaview                                           0.086409
# neighbourhood_cleansed_Seward Park                                      -0.009577
# neighbourhood_cleansed_South Beacon Hill                                -0.002694
# neighbourhood_cleansed_South Delridge                                   -0.004262
# neighbourhood_cleansed_South Lake Union                                  0.062353
# neighbourhood_cleansed_South Park                                       -0.001904
# neighbourhood_cleansed_Southeast Magnolia                               -0.005724
# neighbourhood_cleansed_Stevens                                          -0.012314
# neighbourhood_cleansed_Sunset Hill                                       0.101284
# neighbourhood_cleansed_University District                              -0.016087
# neighbourhood_cleansed_Victory Heights                                  -0.004262
# neighbourhood_cleansed_View Ridge                                       -0.003300
# neighbourhood_cleansed_Wallingford                                       0.031573
# neighbourhood_cleansed_Wedgwood                                         -0.004262
# neighbourhood_cleansed_West Queen Anne                                  -0.011360
# neighbourhood_cleansed_West Woodland                                    -0.011025
# neighbourhood_cleansed_Westlake                                          0.146432
# neighbourhood_cleansed_Whittier Heights                                 -0.008112
# ...
# neighbourhood_cleansed_South Delridge                                0.043460
# neighbourhood_cleansed_South Lake Union                              0.013027
# neighbourhood_cleansed_South Park                                    0.019417
# neighbourhood_cleansed_Southeast Magnolia                            0.013627
# neighbourhood_cleansed_Stevens                                       0.005842
# neighbourhood_cleansed_Sunset Hill                                  -0.025383
# neighbourhood_cleansed_University District                          -0.071040
# neighbourhood_cleansed_Victory Heights                              -0.016503
# neighbourhood_cleansed_View Ridge                                   -0.017935
# neighbourhood_cleansed_Wallingford                                   0.000427
# neighbourhood_cleansed_Wedgwood                                     -0.036491
# neighbourhood_cleansed_West Queen Anne                               0.047343
# neighbourhood_cleansed_West Woodland                                 0.026250
# neighbourhood_cleansed_Westlake                                     -0.017935
# neighbourhood_cleansed_Whittier Heights                              0.019315
# neighbourhood_cleansed_Windermere                                   -0.028162
# neighbourhood_cleansed_Yesler Terrace                                0.013627
# host_response_time_a few days or more                               -0.098065
# host_response_time_within a day                                     -0.458191
# host_response_time_within a few hours                               -0.725807
# host_response_time_within an hour                                    1.000000
# cancellation_policy_flexible                                        -0.082426
# cancellation_policy_moderate                                        -0.020340
# cancellation_policy_strict                                           0.081935
#
#                                             cancellation_policy_flexible  \
# host_response_rate                                             -0.070824
# host_acceptance_rate                                            0.010154
# accommodates                                                   -0.157123
# bathrooms                                                      -0.047131
# bedrooms                                                       -0.120771
# beds                                                           -0.123905
# price                                                          -0.132397
# cleaning_fee                                                   -0.218682
# guests_included                                                -0.124046
# minimum_nights                                                 -0.019478
# maximum_nights                                                  0.060031
# number_of_reviews                                              -0.088753
# review_scores_rating                                            0.054013
# review_scores_accuracy                                          0.007962
# review_scores_cleanliness                                      -0.000319
# review_scores_checkin                                           0.063675
# review_scores_communication                                     0.041616
# review_scores_location                                          0.039958
# review_scores_value                                             0.054763
# instant_bookable_f                                              0.036381
# instant_bookable_t                                             -0.036381
# bed_type_Airbed                                                 0.067014
# bed_type_Couch                                                  0.049880
# bed_type_Futon                                                  0.033903
# bed_type_Pull-out Sofa                                          0.081863
# bed_type_Real Bed                                              -0.111478
# room_type_Entire home/apt                                      -0.116325
# room_type_Private room                                          0.103481
# room_type_Shared room                                           0.046283
# property_type_Apartment                                        -0.012117
# ...                                                                  ...
# neighbourhood_cleansed_Ravenna                                 -0.015359
# neighbourhood_cleansed_Riverview                               -0.017596
# neighbourhood_cleansed_Roosevelt                               -0.004225
# neighbourhood_cleansed_Seaview                                 -0.008084
# neighbourhood_cleansed_Seward Park                             -0.027570
# neighbourhood_cleansed_South Beacon Hill                       -0.014363
# neighbourhood_cleansed_South Delridge                           0.003419
# neighbourhood_cleansed_South Lake Union                         0.008865
# neighbourhood_cleansed_South Park                              -0.010154
# neighbourhood_cleansed_Southeast Magnolia                      -0.030522
# neighbourhood_cleansed_Stevens                                  0.035672
# neighbourhood_cleansed_Sunset Hill                             -0.024903
# neighbourhood_cleansed_University District                     -0.028574
# neighbourhood_cleansed_Victory Heights                          0.055710
# neighbourhood_cleansed_View Ridge                               0.049880
# neighbourhood_cleansed_Wallingford                              0.020806
# neighbourhood_cleansed_Wedgwood                                -0.022727
# neighbourhood_cleansed_West Queen Anne                         -0.040667
# neighbourhood_cleansed_West Woodland                            0.002695
# neighbourhood_cleansed_Westlake                                 0.016142
# neighbourhood_cleansed_Whittier Heights                        -0.001787
# neighbourhood_cleansed_Windermere                              -0.020323
# neighbourhood_cleansed_Yesler Terrace                           0.047507
# host_response_time_a few days or more                           0.051334
# host_response_time_within a day                                 0.073294
# host_response_time_within a few hours                           0.024538
# host_response_time_within an hour                              -0.082426
# cancellation_policy_flexible                                    1.000000
# cancellation_policy_moderate                                   -0.335276
# cancellation_policy_strict                                     -0.438938
#
#                                             cancellation_policy_moderate  \
# host_response_rate                                              0.028530
# host_acceptance_rate                                           -0.030285
# accommodates                                                   -0.158255
# bathrooms                                                      -0.116432
# bedrooms                                                       -0.128143
# beds                                                           -0.140276
# price                                                          -0.152276
# cleaning_fee                                                   -0.184235
# guests_included                                                -0.079040
# minimum_nights                                                  0.028581
# maximum_nights                                                 -0.043927
# number_of_reviews                                               0.085372
# review_scores_rating                                            0.013385
# review_scores_accuracy                                          0.053656
# review_scores_cleanliness                                       0.029060
# review_scores_checkin                                           0.058245
# review_scores_communication                                     0.056030
# review_scores_location                                         -0.005452
# review_scores_value                                             0.052178
# instant_bookable_f                                             -0.046814
# instant_bookable_t                                              0.046814
# bed_type_Airbed                                                -0.033111
# bed_type_Couch                                                 -0.001196
# bed_type_Futon                                                  0.015676
# bed_type_Pull-out Sofa                                         -0.003400
# bed_type_Real Bed                                               0.005425
# room_type_Entire home/apt                                      -0.053313
# room_type_Private room                                          0.079404
# room_type_Shared room                                          -0.067582
# property_type_Apartment                                        -0.073814
# ...                                                                  ...
# neighbourhood_cleansed_Ravenna                                  0.021062
# neighbourhood_cleansed_Riverview                               -0.001196
# neighbourhood_cleansed_Roosevelt                                0.044895
# neighbourhood_cleansed_Seaview                                  0.019985
# neighbourhood_cleansed_Seward Park                              0.040152
# neighbourhood_cleansed_South Beacon Hill                        0.009978
# neighbourhood_cleansed_South Delridge                          -0.015411
# neighbourhood_cleansed_South Lake Union                        -0.010896
# neighbourhood_cleansed_South Park                               0.030285
# neighbourhood_cleansed_Southeast Magnolia                      -0.002075
# neighbourhood_cleansed_Stevens                                 -0.009349
# neighbourhood_cleansed_Sunset Hill                              0.017299
# neighbourhood_cleansed_University District                     -0.000142
# neighbourhood_cleansed_Victory Heights                          0.005388
# neighbourhood_cleansed_View Ridge                              -0.001196
# neighbourhood_cleansed_Wallingford                             -0.036643
# neighbourhood_cleansed_Wedgwood                                 0.046987
# neighbourhood_cleansed_West Queen Anne                          0.022282
# neighbourhood_cleansed_West Woodland                            0.012308
# neighbourhood_cleansed_Westlake                                -0.028035
# neighbourhood_cleansed_Whittier Heights                         0.041049
# neighbourhood_cleansed_Windermere                               0.014118
# neighbourhood_cleansed_Yesler Terrace                          -0.033111
# host_response_time_a few days or more                           0.021394
# host_response_time_within a day                                -0.005601
# host_response_time_within a few hours                           0.022503
# host_response_time_within an hour                              -0.020340
# cancellation_policy_flexible                                   -0.335276
# cancellation_policy_moderate                                    1.000000
# cancellation_policy_strict                                     -0.699346
#
#                                             cancellation_policy_strict
# host_response_rate                                            0.026525
# host_acceptance_rate                                          0.021180
# accommodates                                                  0.270139
# bathrooms                                                     0.146801
# bedrooms                                                      0.213841
# beds                                                          0.227790
# price                                                         0.245678
# cleaning_fee                                                  0.341622
# guests_included                                               0.169495
# minimum_nights                                               -0.012480
# maximum_nights                                               -0.003651
# number_of_reviews                                            -0.014084
# review_scores_rating                                         -0.053745
# review_scores_accuracy                                       -0.057213
# review_scores_cleanliness                                    -0.027473
# review_scores_checkin                                        -0.103859
# review_scores_communication                                  -0.085011
# review_scores_location                                       -0.025116
# review_scores_value                                          -0.091311
# instant_bookable_f                                            0.017045
# instant_bookable_t                                           -0.017045
# bed_type_Airbed                                              -0.019265
# bed_type_Couch                                               -0.036703
# bed_type_Futon                                               -0.040673
# bed_type_Pull-out Sofa                                       -0.058866
# bed_type_Real Bed                                             0.079404
# room_type_Entire home/apt                                     0.139101
# room_type_Private room                                       -0.154240
# room_type_Shared room                                         0.029339
# property_type_Apartment                                       0.079591
# ...                                                                ...
# neighbourhood_cleansed_Ravenna                               -0.008434
# neighbourhood_cleansed_Riverview                              0.014491
# neighbourhood_cleansed_Roosevelt                             -0.039611
# neighbourhood_cleansed_Seaview                               -0.012927
# neighbourhood_cleansed_Seward Park                           -0.017376
# neighbourhood_cleansed_South Beacon Hill                      0.001381
# neighbourhood_cleansed_South Delridge                         0.012104
# neighbourhood_cleansed_South Lake Union                       0.003666
# neighbourhood_cleansed_South Park                            -0.021180
# neighbourhood_cleansed_Southeast Magnolia                     0.025135
# neighbourhood_cleansed_Stevens                               -0.018148
# neighbourhood_cleansed_Sunset Hill                            0.002395
# neighbourhood_cleansed_University District                    0.021815
# neighbourhood_cleansed_Victory Heights                       -0.047406
# neighbourhood_cleansed_View Ridge                            -0.036703
# neighbourhood_cleansed_Wallingford                            0.019162
# neighbourhood_cleansed_Wedgwood                              -0.027569
# neighbourhood_cleansed_West Queen Anne                        0.009603
# neighbourhood_cleansed_West Woodland                         -0.013783
# neighbourhood_cleansed_Westlake                               0.014491
# neighbourhood_cleansed_Whittier Heights                      -0.037793
# neighbourhood_cleansed_Windermere                             0.001955
# neighbourhood_cleansed_Yesler Terrace                        -0.004465
# host_response_time_a few days or more                        -0.059350
# host_response_time_within a day                              -0.050266
# host_response_time_within a few hours                        -0.040078
# host_response_time_within an hour                             0.081935
# cancellation_policy_flexible                                 -0.438938
# cancellation_policy_moderate                                 -0.699346
# cancellation_policy_strict                                    1.000000
#
# [220 rows x 220 columns]

# %%
# Plot all of the variable-to-variable relations as scatterplots

sns.pairplot(listingdf)

# %%
listingdf.columns
list = []
for col in listingdf.columns:
    list.append(col)
    
#list = "','".join(list)
print(list)

# %%
# Create your feature matrix (X) and target vector (y)
y, X = patsy.dmatrices('price ~ host_response_time + host_response_rate + host_acceptance_rate + host_is_superhost + neighbourhood_cleansed + property_type + room_type + accommodates + bathrooms + bedrooms + beds + bed_type + cleaning_fee + guests_included + minimum_nights + maximum_nights + number_of_reviews + review_scores_rating + review_scores_accuracy + review_scores_cleanliness + review_scores_checkin + review_scores_communication + review_scores_location + review_scores_value + instant_bookable + cancellation_policy', data=listingdf, return_type="dataframe")

# Create your model
model = sm.OLS(y,X)
# Fit your model to your training set
fit = model.fit()
# Print summary statistics of the model's performance
fit.summary()

# %%
fit.resid.plot(style='o', figsize=(12,8));

# %%
# p = model.fit().params
# x = np.arange(1, 3)
# ax = df.plot(x='host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'cleaning_fee', 'guests_included', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'cancellation_policy'
#             , y='price', kind='scatter')


# # X = np.array(['host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'cleaning_fee', 'guests_included', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'cancellation_policy'])
# # y = np.array(['price'])

# # sns.regplot(x = X , y = y , data=listingdf)

# %%
#X = listingdf['host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'cleaning_fee', 'guests_included', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'cancellation_policy']

# %%
fig, ax = plt.subplots(figsize=(8,6))


ax.plot(X, y, 'o', label="Data")
#ax.plot(X, y, 'b-', label="True")
#ax.plot(X, fit.fittedvalues, 'r--.', label="Predicted")
# ax.plot(X, iv_u, 'r--')
# ax.plot(X, iv_l, 'r--')
#legend = ax.legend(loc="best")

# %%
#Relationship between "accommodates", "bathrooms", "bedrooms", "beds" vs "price"

sns.pairplot(listingdf, x_vars=["accommodates", "bathrooms", "bedrooms", "beds"], y_vars=["price"],
             size=5, aspect=.8, kind="reg");

# %%
#Relationship between "host_response_rate","host_acceptance_rate" vs "price"

sns.pairplot(listingdf, x_vars=["host_response_rate","host_acceptance_rate"], y_vars=["price"],
             size=5, aspect=.8, kind="reg");

# %%
#Relationship between "host_response_rate","host_acceptance_rate" vs "price"

sns.pairplot(listingdf, x_vars=["cancellation_policy"], y_vars=["price"],
             size=5, aspect=.8, kind="reg");

# %%
# $range between "property_type" -> may need to analysis diff property type separately?


sns.pairplot(listingdf, x_vars=["property_type"], y_vars=["price"],
             size=15, aspect=0.8, kind="reg");

# %%
sns.countplot(x="property_type", data=listingdf, palette="Greens_d");

# %%
lm1 = smf.ols('price ~ host_response_time + host_response_rate + host_acceptance_rate + host_is_superhost + neighbourhood_cleansed + property_type + room_type + accommodates + bathrooms + bedrooms + beds + bed_type + cleaning_fee + guests_included + minimum_nights + maximum_nights + number_of_reviews + review_scores_rating + review_scores_accuracy + review_scores_cleanliness + review_scores_checkin + review_scores_communication + review_scores_location + review_scores_value + instant_bookable + cancellation_policy', data=listingdf)

fit2 = lm1.fit()
fit2.summary()

# %%
fig, ax = plt.subplots(figsize=(12))
fig = sm.graphics.plot_partregress('price', 'accommodates' , ['accommodates','proprty_type'], data=fit, ax=ax)
